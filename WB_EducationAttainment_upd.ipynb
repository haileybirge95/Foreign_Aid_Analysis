# %% [markdown]
# # World Bank - Education Attainment Summarizing
# Reduced '.csv' files from WB_data Notebook

# %%
# Dependencies and Setup
import pandas as pd
from pathlib import Path
import requests
import matplotlib.pyplot as plt
from matplotlib import cbook
from scipy.stats import linregress
import scipy.stats as st
import numpy as np
import time


# Impor the OpenWeatherMap API key
from api_keys import geoapify_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %%
# WB data set
WB_africadata_2000_bins = Path("Resources\WB_africadata_2000_bins.csv")

# %%
# Read data file with the Pandas library
# encoding?, i.e encoding="ISO-8859-1"
WB_africadata_2000_df2 = pd.read_csv(WB_africadata_2000_bins)

# %%
WB_africadata_2000_df2
# Out:
#                 series_id country_code country_name  year         value  \
# 0          SH.HIV.INCD.TL          KEN        Kenya  2017  3.400000e+04
# 1          SH.HIV.INCD.TL          LBR      Liberia  2017  1.600000e+03
# 2          SH.HIV.INCD.TL          LSO      Lesotho  2017  1.000000e+04
# 3          SH.HIV.INCD.TL          MDG   Madagascar  2017  7.200000e+03
# 4          SH.HIV.INCD.TL          MOZ   Mozambique  2017  1.300000e+05
# ...                   ...          ...          ...   ...           ...
# 652157          VA.NO.SRC          WSM        Samoa  2006  3.000000e+00
# 652158  FM.LBL.BMNY.GD.ZS          TCD         Chad  2010  1.146678e+01
# 652159  NE.CON.PRVT.CN.AD          SDN        Sudan  2000  2.199464e+10
# 652160  NE.CON.PRVT.CN.AD          SDN        Sudan  2003  3.190503e+10
# 652161     SP.POP.DPND.YG          TGO         Togo  2013  7.513357e+01
#
#          Year Group
# 0       2016 - 2020
# 1       2016 - 2020
# 2       2016 - 2020
# 3       2016 - 2020
# 4       2016 - 2020
# ...             ...
# 652157  2006 - 2010
# 652158  2006 - 2010
# 652159  2000 - 2005
# 652160  2000 - 2005
# 652161  2011 - 2015
#
# [652162 rows x 6 columns]

# %% [markdown]
# # Slicing of the Data
# ###In order to analyze the data and to understand the impact of the Foreign Aid with regards to poverty rate, literacy and mortality, the data was sliced by the "series_id". The deifinition of the diferent "series_id" values (indicators) is described in a second file downloaded from the Nasdaq API and saved as 'WB_metadata_df'.
#
# ###To facilitate/expedite the search and filtering of the relevant a function was created to search the text strings : "key_word". This function is case sensitive and it's used is combined with the review of the search output selection to identify the indicators that best match our work objective.

# %%
# WB id series definition data set
WB_metadata = Path("Resources/WB_METADATA_f7ce7fba293ccc6eb39cdf15fb097982.csv")

# %%
# Read data file with the Pandas library
WB_metadata_df = pd.read_csv(WB_metadata)

# %%
WB_metadata_df
# Out:
#                     series_id  \
# 0              DC.DAC.DEUL.CD
# 1                  RQ.STD.ERR
# 2           EG.USE.PCAP.KG.OE
# 3           EN.POP.EL5M.UR.ZS
# 4     per_lm_alllm.cov_q1_tot
# ...                       ...
# 1479        SL.TLF.BASC.FE.ZS
# 1480        SL.GDP.PCAP.EM.KD
# 1481        SL.TLF.INTM.MA.ZS
# 1482        SL.UEM.NEET.FE.ZS
# 1483        SL.UEM.NEET.MA.ZS
#
#                                                    name  \
# 0     Net bilateral aid flows from DAC donors, Germa...
# 1                    Regulatory Quality: Standard Error
# 2          Energy use (kg of oil equivalent per capita)
# 3     Urban population living in areas where elevati...
# 4     Coverage of unemployment benefits and ALMP in ...
# ...                                                 ...
# 1479  Labor force with basic education, female (% of...
# 1480      GDP per person employed (constant 2021 PPP $)
# 1481  Labor force with intermediate education, male ...
# 1482  Share of youth not in education, employment or...
# 1483  Share of youth not in education, employment or...
#
#                                             description
# 0     Net bilateral aid flows from DAC donors are th...
# 1     Regulatory Quality captures perceptions of the...
# 2     Energy use refers to use of primary energy bef...
# 3     Urban population below 5m is the percentage of...
# 4     Coverage of unemployment benefits and active l...
# ...                                                 ...
# 1479  The ratio of the labor force with basic educat...
# 1480  GDP per person employed is gross domestic prod...
# 1481  The ratio of the labor force with intermediate...
# 1482  Share of youth not in education, employment or...
# 1483  Share of youth not in education, employment or...
#
# [1484 rows x 3 columns]

# %%
# This function will search within a text string for a given 'key word'. It is case sensitive

def key_word(df, search_col, word_txt, result_col):
    i=0   
    result_ls = []
    for item in df[search_col]:
        text_ls = [x.strip() for x in df[search_col][i].split()]
        if word_txt in text_ls:
            result_ls.append(df[result_col][i])
        i+=1
    if i >= df[search_col].count():
        if len(result_ls) > 0:
            return result_ls
        else:
            return print("Keyword Not found")

# %%
education_search = key_word(WB_metadata_df, 'name', 'Educational', 'series_id')

# %%
#len(education_search)

# %%
education_search2= WB_metadata_df[WB_metadata_df['series_id'].isin(education_search)]

# %%
#education_search2

# %% [markdown]
# # Selection of Indicators for Analysis
#
# ###Indicators are selected out of the search result and used to create redu ed data sets. In the case of the Mortality indicator, we selected three indicators : mortality under age 5-females only, mortality under age 5-males only, and mortality under age 5-combined. Values listed are the rate per 100,000 parts.
#
# ###In order to organize the data, we prepared 6 data sets. One for each indicator.

# %%
# Literacy indicators : percentage of population
#SE.SEC.CUAT.LO.ZS - The percentage of population ages 25 and over that attained or completed lower secondary education.
#SE.SEC.CUAT.UP.ZS - The percentage of population ages 25 and over that attained or completed upper secondary education.
#SE.TER.CUAT.MS.ZS - The percentage of population ages 25 and over that attained or completed Master's or equivalent.

# %% [markdown]
# ## Educational Attainment : Lower Secondary (% Pop.> 25yrs)

# %%
WB_Educ_LS_df = WB_africadata_2000_df2.loc[WB_africadata_2000_df2['series_id'] == "SE.SEC.CUAT.LO.ZS"]
#WB_Educ_LS_df = WB_Educ_LS_df.rename(columns = {'value': 'Lower Secondary Educ. (% Pop.> 25yrs)'})
WB_Educ_LS_df
# Out:
#                 series_id country_code  country_name  year      value  \
# 133129  SE.SEC.CUAT.LO.ZS          RWA        Rwanda  2010  12.582890
# 324759  SE.SEC.CUAT.LO.ZS          TZA      Tanzania  2002   5.986470
# 324760  SE.SEC.CUAT.LO.ZS          UGA        Uganda  2002  11.518880
# 324761  SE.SEC.CUAT.LO.ZS          ZWE      Zimbabwe  2002  46.016670
# 324762  SE.SEC.CUAT.LO.ZS          SLE  Sierra Leone  2003  16.482738
# ...                   ...          ...           ...   ...        ...
# 324894  SE.SEC.CUAT.LO.ZS          KEN         Kenya  2022  64.952110
# 324895  SE.SEC.CUAT.LO.ZS          NGA       Nigeria  2022  69.982292
# 324896  SE.SEC.CUAT.LO.ZS          RWA        Rwanda  2022  17.950159
# 324897  SE.SEC.CUAT.LO.ZS          SOM       Somalia  2022  11.111570
# 324898  SE.SEC.CUAT.LO.ZS          ZMB        Zambia  2022  65.410141
#
#          Year Group
# 133129  2006 - 2010
# 324759  2000 - 2005
# 324760  2000 - 2005
# 324761  2000 - 2005
# 324762  2000 - 2005
# ...             ...
# 324894  2021 - 2023
# 324895  2021 - 2023
# 324896  2021 - 2023
# 324897  2021 - 2023
# 324898  2021 - 2023
#
# [141 rows x 6 columns]

# %%
reduc_Educ_LS_df = WB_Educ_LS_df.reset_index()
reduc_Educ_LS_df.drop(columns=['index','series_id'], inplace=True)
reduc_Educ_LS_df
# Out:
#     country_code  country_name  year      value   Year Group
# 0            RWA        Rwanda  2010  12.582890  2006 - 2010
# 1            TZA      Tanzania  2002   5.986470  2000 - 2005
# 2            UGA        Uganda  2002  11.518880  2000 - 2005
# 3            ZWE      Zimbabwe  2002  46.016670  2000 - 2005
# 4            SLE  Sierra Leone  2003  16.482738  2000 - 2005
# ..           ...           ...   ...        ...          ...
# 136          KEN         Kenya  2022  64.952110  2021 - 2023
# 137          NGA       Nigeria  2022  69.982292  2021 - 2023
# 138          RWA        Rwanda  2022  17.950159  2021 - 2023
# 139          SOM       Somalia  2022  11.111570  2021 - 2023
# 140          ZMB        Zambia  2022  65.410141  2021 - 2023
#
# [141 rows x 5 columns]

# %%
Educ_LS_table = reduc_Educ_LS_df.pivot(index='year', columns='country_name', values='value')
Educ_LS_table
# Out:
# country_name     Angola   Botswana  Burkina Faso  Central African Republic  \
# year
# 2002                NaN        NaN           NaN                       NaN
# 2003                NaN        NaN           NaN                       NaN
# 2004          22.165590        NaN           NaN                       NaN
# 2005                NaN        NaN           NaN                       NaN
# 2006                NaN        NaN       7.93816                       NaN
# 2007                NaN        NaN       2.03617                       NaN
# 2008                NaN        NaN           NaN                       NaN
# 2009          10.561316        NaN           NaN                       NaN
# 2010                NaN        NaN           NaN                       NaN
# 2011          22.868460        NaN           NaN                       NaN
# 2012                NaN        NaN           NaN                       NaN
# 2013                NaN        NaN           NaN                       NaN
# 2014          28.923470        NaN       8.48835                       NaN
# 2015          27.969761        NaN           NaN                       NaN
# 2016                NaN        NaN           NaN                       NaN
# 2017                NaN        NaN           NaN                       NaN
# 2018                NaN        NaN      12.67080                       NaN
# 2019          38.469933  67.608025      14.00146                  12.54875
# 2020                NaN  68.738220           NaN                       NaN
# 2021          39.977886  71.157555      11.45341                       NaN
# 2022                NaN  70.004646           NaN                       NaN
#
# country_name       Chad   Djibouti  Egypt, Arab Rep.  Ethiopia      Ghana  \
# year
# 2002                NaN        NaN               NaN       NaN        NaN
# 2003                NaN        NaN               NaN       NaN        NaN
# 2004                NaN        NaN               NaN       NaN        NaN
# 2005                NaN        NaN               NaN       NaN        NaN
# 2006                NaN        NaN         44.430729       NaN  40.595158
# 2007                NaN        NaN               NaN   7.21509        NaN
# 2008                NaN        NaN               NaN       NaN        NaN
# 2009          10.044390        NaN               NaN       NaN        NaN
# 2010                NaN        NaN               NaN       NaN  54.319618
# 2011                NaN        NaN               NaN  12.51169        NaN
# 2012                NaN        NaN               NaN       NaN        NaN
# 2013                NaN        NaN               NaN  17.65864  50.914597
# 2014                NaN        NaN               NaN       NaN        NaN
# 2015                NaN        NaN               NaN       NaN  51.817280
# 2016                NaN        NaN               NaN  11.08273        NaN
# 2017                NaN  23.784451         72.959137       NaN  46.434349
# 2018          13.263819        NaN               NaN       NaN        NaN
# 2019           8.839040        NaN               NaN  10.34380        NaN
# 2020                NaN        NaN         52.602589       NaN        NaN
# 2021                NaN        NaN         51.787548       NaN        NaN
# 2022                NaN        NaN               NaN       NaN        NaN
#
# country_name      Kenya  ...    Senegal  Sierra Leone   Somalia      Sudan  \
# year                     ...
# 2002                NaN  ...        NaN           NaN       NaN        NaN
# 2003                NaN  ...        NaN     16.482738       NaN        NaN
# 2004                NaN  ...        NaN     18.937050       NaN        NaN
# 2005                NaN  ...        NaN           NaN       NaN        NaN
# 2006                NaN  ...   7.547190           NaN       NaN        NaN
# 2007                NaN  ...        NaN           NaN       NaN        NaN
# 2008                NaN  ...        NaN           NaN       NaN        NaN
# 2009          32.911598  ...        NaN           NaN       NaN        NaN
# 2010          29.073750  ...        NaN           NaN       NaN        NaN
# 2011                NaN  ...  10.846010           NaN       NaN  27.881702
# 2012                NaN  ...        NaN           NaN       NaN        NaN
# 2013                NaN  ...  13.885420           NaN       NaN        NaN
# 2014                NaN  ...        NaN     74.666176       NaN        NaN
# 2015                NaN  ...  10.674130           NaN       NaN        NaN
# 2016                NaN  ...  12.337450           NaN       NaN        NaN
# 2017                NaN  ...  17.824829     22.741819       NaN        NaN
# 2018                NaN  ...  13.164990     21.565147       NaN        NaN
# 2019          60.519951  ...  12.795060     23.148621       NaN        NaN
# 2020          58.755699  ...        NaN           NaN       NaN        NaN
# 2021          72.792580  ...        NaN           NaN       NaN        NaN
# 2022          64.952110  ...        NaN           NaN  11.11157        NaN
#
# country_name   Tanzania       Togo    Tunisia     Uganda     Zambia   Zimbabwe
# year
# 2002           5.986470        NaN        NaN  11.518880        NaN  46.016670
# 2003                NaN        NaN        NaN        NaN        NaN        NaN
# 2004                NaN        NaN        NaN        NaN        NaN        NaN
# 2005                NaN        NaN        NaN        NaN        NaN        NaN
# 2006                NaN        NaN        NaN        NaN        NaN        NaN
# 2007                NaN        NaN        NaN        NaN        NaN        NaN
# 2008          13.809693        NaN  37.081161  23.627661        NaN        NaN
# 2009                NaN  26.944210        NaN        NaN        NaN        NaN
# 2010          11.699676        NaN  39.334690  28.830111        NaN        NaN
# 2011                NaN  18.270750  40.507160        NaN        NaN        NaN
# 2012          11.026600        NaN  39.824009  24.025860        NaN  60.759121
# 2013                NaN        NaN        NaN        NaN        NaN        NaN
# 2014                NaN        NaN        NaN        NaN        NaN  58.763168
# 2015          11.793240  54.060268        NaN        NaN        NaN  53.486809
# 2016                NaN        NaN  44.590710  19.189699        NaN        NaN
# 2017                NaN  21.106899        NaN  28.176649  47.303745  64.935226
# 2018          11.489070        NaN  42.709091        NaN  37.650219        NaN
# 2019                NaN  32.406658  43.251930        NaN  61.345318  88.234215
# 2020           3.031986        NaN        NaN        NaN  66.040390        NaN
# 2021                NaN        NaN        NaN  39.458057  63.898285  89.623985
# 2022                NaN        NaN        NaN        NaN  65.410141        NaN
#
# [21 rows x 30 columns]

# %% [markdown]
# ## Educational Attainment : Upper Secondary (% Pop.> 25yrs)

# %%
WB_Educ_US_df = WB_africadata_2000_df2.loc[WB_africadata_2000_df2['series_id'] == "SE.SEC.CUAT.UP.ZS"]
WB_Educ_US_df
# Out:
#                 series_id country_code  country_name  year      value  \
# 60104   SE.SEC.CUAT.UP.ZS          WSM         Samoa  2001  63.037628
# 60105   SE.SEC.CUAT.UP.ZS          TZA      Tanzania  2002   1.622880
# 60106   SE.SEC.CUAT.UP.ZS          UGA        Uganda  2002   6.453940
# 60107   SE.SEC.CUAT.UP.ZS          ZWE      Zimbabwe  2002  10.357510
# 60108   SE.SEC.CUAT.UP.ZS          SLE  Sierra Leone  2003   4.066010
# ...                   ...          ...           ...   ...        ...
# 149288  SE.SEC.CUAT.UP.ZS          ZWE      Zimbabwe  2017  12.264890
# 149290  SE.SEC.CUAT.UP.ZS          KEN         Kenya  2019  33.388390
# 149292  SE.SEC.CUAT.UP.ZS          ZMB        Zambia  2021  36.321079
# 149293  SE.SEC.CUAT.UP.ZS          ZWE      Zimbabwe  2021  64.132111
# 651177  SE.SEC.CUAT.UP.ZS          NGA       Nigeria  2018  40.092579
#
#          Year Group
# 60104   2000 - 2005
# 60105   2000 - 2005
# 60106   2000 - 2005
# 60107   2000 - 2005
# 60108   2000 - 2005
# ...             ...
# 149288  2016 - 2020
# 149290  2016 - 2020
# 149292  2021 - 2023
# 149293  2021 - 2023
# 651177  2016 - 2020
#
# [138 rows x 6 columns]

# %%
reduc_Educ_US_df = WB_Educ_US_df.reset_index()
reduc_Educ_US_df.drop(columns=['index','series_id'], inplace=True)
reduc_Educ_US_df
# Out:
#     country_code  country_name  year      value   Year Group
# 0            WSM         Samoa  2001  63.037628  2000 - 2005
# 1            TZA      Tanzania  2002   1.622880  2000 - 2005
# 2            UGA        Uganda  2002   6.453940  2000 - 2005
# 3            ZWE      Zimbabwe  2002  10.357510  2000 - 2005
# 4            SLE  Sierra Leone  2003   4.066010  2000 - 2005
# ..           ...           ...   ...        ...          ...
# 133          ZWE      Zimbabwe  2017  12.264890  2016 - 2020
# 134          KEN         Kenya  2019  33.388390  2016 - 2020
# 135          ZMB        Zambia  2021  36.321079  2021 - 2023
# 136          ZWE      Zimbabwe  2021  64.132111  2021 - 2023
# 137          NGA       Nigeria  2018  40.092579  2016 - 2020
#
# [138 rows x 5 columns]

# %%
Educ_US_table = reduc_Educ_US_df.pivot(index='year', columns='country_name', values='value')
Educ_US_table
# Out:
# country_name     Angola   Botswana  Burkina Faso  Central African Republic  \
# year
# 2001                NaN        NaN           NaN                       NaN
# 2002                NaN        NaN           NaN                       NaN
# 2003                NaN        NaN           NaN                       NaN
# 2004           6.494953        NaN           NaN                       NaN
# 2005                NaN        NaN           NaN                       NaN
# 2006                NaN        NaN       4.00732                       NaN
# 2007                NaN        NaN       0.49510                       NaN
# 2008                NaN        NaN           NaN                       NaN
# 2009           7.719856        NaN           NaN                       NaN
# 2010                NaN        NaN           NaN                       NaN
# 2011          12.303003        NaN           NaN                       NaN
# 2012                NaN        NaN           NaN                       NaN
# 2013                NaN        NaN           NaN                       NaN
# 2014          15.863530        NaN       2.80549                       NaN
# 2015          17.436510        NaN           NaN                       NaN
# 2016                NaN        NaN           NaN                       NaN
# 2017                NaN        NaN           NaN                       NaN
# 2018                NaN        NaN       6.15245                       NaN
# 2019          20.841118  42.949219       7.82172                   5.61245
# 2020                NaN  43.735836           NaN                       NaN
# 2021          22.049187  44.229374       6.34940                       NaN
# 2022                NaN  44.884315           NaN                       NaN
#
# country_name      Chad  Djibouti  Egypt, Arab Rep.  Ethiopia      Ghana  \
# year
# 2001               NaN       NaN               NaN       NaN        NaN
# 2002               NaN       NaN               NaN       NaN        NaN
# 2003               NaN       NaN               NaN       NaN        NaN
# 2004          5.519980       NaN               NaN       NaN        NaN
# 2005               NaN       NaN               NaN       NaN        NaN
# 2006               NaN       NaN         40.380260       NaN  12.395874
# 2007               NaN       NaN               NaN  7.024190        NaN
# 2008               NaN       NaN               NaN       NaN        NaN
# 2009          5.104420       NaN               NaN       NaN        NaN
# 2010               NaN       NaN               NaN       NaN  20.563971
# 2011               NaN       NaN               NaN  8.836050        NaN
# 2012               NaN       NaN               NaN       NaN        NaN
# 2013               NaN       NaN               NaN  7.833063  18.847855
# 2014               NaN       NaN               NaN       NaN        NaN
# 2015               NaN       NaN               NaN       NaN  22.084148
# 2016               NaN       NaN               NaN  6.929630        NaN
# 2017               NaN  15.62372         67.156471       NaN  15.598560
# 2018          7.483197       NaN               NaN       NaN        NaN
# 2019          4.556900       NaN               NaN  4.524770        NaN
# 2020               NaN       NaN         52.602589       NaN        NaN
# 2021               NaN       NaN         51.787548       NaN        NaN
# 2022               NaN       NaN               NaN       NaN        NaN
#
# country_name      Kenya  ...   Senegal  Sierra Leone  Somalia      Sudan  \
# year                     ...
# 2001                NaN  ...       NaN           NaN      NaN        NaN
# 2002                NaN  ...       NaN           NaN      NaN        NaN
# 2003                NaN  ...       NaN      4.066010      NaN        NaN
# 2004                NaN  ...       NaN     12.129740      NaN        NaN
# 2005                NaN  ...       NaN           NaN      NaN        NaN
# 2006                NaN  ...   4.92511           NaN      NaN        NaN
# 2007                NaN  ...       NaN           NaN      NaN        NaN
# 2008                NaN  ...       NaN           NaN      NaN        NaN
# 2009          27.056290  ...       NaN           NaN      NaN        NaN
# 2010          22.028610  ...       NaN           NaN      NaN        NaN
# 2011                NaN  ...   5.61641           NaN      NaN  23.044186
# 2012                NaN  ...       NaN           NaN      NaN        NaN
# 2013                NaN  ...   8.23461           NaN      NaN        NaN
# 2014                NaN  ...       NaN     51.155487      NaN        NaN
# 2015                NaN  ...   5.71198           NaN      NaN        NaN
# 2016                NaN  ...   6.90667           NaN      NaN        NaN
# 2017                NaN  ...  10.86295      8.161480      NaN        NaN
# 2018                NaN  ...   7.19961     14.827837      NaN        NaN
# 2019          33.388390  ...   7.41092     12.092690      NaN        NaN
# 2020          29.375179  ...       NaN           NaN      NaN        NaN
# 2021          43.907658  ...       NaN           NaN      NaN        NaN
# 2022          37.576099  ...       NaN           NaN  9.80752        NaN
#
# country_name  Tanzania      Togo    Tunisia     Uganda     Zambia   Zimbabwe
# year
# 2001               NaN       NaN        NaN        NaN        NaN        NaN
# 2002          1.622880       NaN        NaN   6.453940        NaN  10.357510
# 2003               NaN       NaN        NaN        NaN        NaN        NaN
# 2004               NaN       NaN        NaN        NaN        NaN        NaN
# 2005               NaN       NaN        NaN        NaN        NaN        NaN
# 2006               NaN       NaN        NaN        NaN        NaN        NaN
# 2007               NaN       NaN        NaN        NaN        NaN        NaN
# 2008          1.635780       NaN        NaN   8.773930        NaN        NaN
# 2009               NaN   8.90192        NaN        NaN        NaN        NaN
# 2010          2.045637       NaN        NaN  10.666730        NaN        NaN
# 2011               NaN   9.25691        NaN        NaN        NaN        NaN
# 2012          3.395960       NaN        NaN   9.869800        NaN   6.083060
# 2013               NaN       NaN        NaN        NaN        NaN        NaN
# 2014               NaN       NaN        NaN        NaN        NaN  15.191990
# 2015          5.273810  44.88625        NaN        NaN        NaN  11.781770
# 2016               NaN       NaN        NaN  12.272820        NaN        NaN
# 2017               NaN   9.46590        NaN  27.541700  29.056843  12.264890
# 2018          4.051950       NaN  25.294460        NaN  19.934450        NaN
# 2019               NaN  11.86906  31.904831        NaN  35.270935  13.274300
# 2020          3.031986       NaN        NaN        NaN  39.453110        NaN
# 2021               NaN       NaN        NaN  38.757221  36.321079  64.132111
# 2022               NaN       NaN        NaN        NaN  38.453289        NaN
#
# [22 rows x 30 columns]

# %%
#WB_Educ_US_df = WB_Educ_US_df.rename(columns = {'value': 'Upper Secondary Educ. (% Pop.> 25yrs)'})
#WB_Educ_US_df

# %% [markdown]
# ## Educational Attainment : Masters (% Pop.> 25yrs)

# %%
WB_Educ_MS_df = WB_africadata_2000_df2.loc[WB_africadata_2000_df2['series_id'] == "SE.TER.CUAT.MS.ZS"]
WB_Educ_MS_df
# Out:
#                 series_id country_code  country_name  year     value  \
# 72191   SE.TER.CUAT.MS.ZS          SLE  Sierra Leone  2003  0.210999
# 72192   SE.TER.CUAT.MS.ZS          AGO        Angola  2004  0.475335
# 72193   SE.TER.CUAT.MS.ZS          MWI        Malawi  2005  0.452600
# 72194   SE.TER.CUAT.MS.ZS          GHA         Ghana  2006  0.240368
# 72195   SE.TER.CUAT.MS.ZS          TZA      Tanzania  2008  0.128440
# ...                   ...          ...           ...   ...       ...
# 72281   SE.TER.CUAT.MS.ZS          ZMB        Zambia  2022  0.317543
# 149610  SE.TER.CUAT.MS.ZS          NGA       Nigeria  2006  1.642740
# 149611  SE.TER.CUAT.MS.ZS          TGO          Togo  2017  1.253972
# 149612  SE.TER.CUAT.MS.ZS          MRT    Mauritania  2019  1.938819
# 149613  SE.TER.CUAT.MS.ZS          NGA       Nigeria  2019  0.697962
#
#          Year Group
# 72191   2000 - 2005
# 72192   2000 - 2005
# 72193   2000 - 2005
# 72194   2006 - 2010
# 72195   2006 - 2010
# ...             ...
# 72281   2021 - 2023
# 149610  2006 - 2010
# 149611  2016 - 2020
# 149612  2016 - 2020
# 149613  2016 - 2020
#
# [90 rows x 6 columns]

# %%
reduc_Educ_MS_df = WB_Educ_MS_df.reset_index()
reduc_Educ_MS_df.drop(columns=['index','series_id'], inplace=True)
reduc_Educ_MS_df
# Out:
#    country_code  country_name  year     value   Year Group
# 0           SLE  Sierra Leone  2003  0.210999  2000 - 2005
# 1           AGO        Angola  2004  0.475335  2000 - 2005
# 2           MWI        Malawi  2005  0.452600  2000 - 2005
# 3           GHA         Ghana  2006  0.240368  2006 - 2010
# 4           TZA      Tanzania  2008  0.128440  2006 - 2010
# ..          ...           ...   ...       ...          ...
# 85          ZMB        Zambia  2022  0.317543  2021 - 2023
# 86          NGA       Nigeria  2006  1.642740  2006 - 2010
# 87          TGO          Togo  2017  1.253972  2016 - 2020
# 88          MRT    Mauritania  2019  1.938819  2016 - 2020
# 89          NGA       Nigeria  2019  0.697962  2016 - 2020
#
# [90 rows x 5 columns]

# %%
Educ_MS_table = reduc_Educ_MS_df.pivot(index='year', columns='country_name', values='value')
Educ_MS_table
# Out:
# country_name    Angola  Botswana  Burkina Faso      Chad  Djibouti  \
# year
# 2003               NaN       NaN           NaN       NaN       NaN
# 2004          0.475335       NaN           NaN       NaN       NaN
# 2005               NaN       NaN           NaN       NaN       NaN
# 2006               NaN       NaN           NaN       NaN       NaN
# 2008               NaN       NaN           NaN       NaN       NaN
# 2009          3.022058       NaN           NaN  0.262690       NaN
# 2010               NaN       NaN           NaN       NaN       NaN
# 2011          0.578822       NaN           NaN       NaN       NaN
# 2012               NaN       NaN           NaN       NaN       NaN
# 2013               NaN       NaN           NaN       NaN       NaN
# 2014          0.257418       NaN       0.00000       NaN       NaN
# 2015               NaN       NaN           NaN       NaN       NaN
# 2016               NaN       NaN           NaN       NaN       NaN
# 2017               NaN       NaN           NaN       NaN       0.0
# 2018               NaN       NaN       1.34101  2.731943       NaN
# 2019          0.020671  1.274187       1.18004       NaN       NaN
# 2020               NaN  0.979797           NaN       NaN       NaN
# 2021          0.000000  1.008132           NaN       NaN       NaN
# 2022               NaN  1.215302           NaN       NaN       NaN
#
# country_name  Egypt, Arab Rep.  Ethiopia     Ghana     Kenya   Lesotho  ...  \
# year                                                                    ...
# 2003                       NaN       NaN       NaN       NaN       NaN  ...
# 2004                       NaN       NaN       NaN       NaN       NaN  ...
# 2005                       NaN       NaN       NaN       NaN       NaN  ...
# 2006                       NaN       NaN  0.240368       NaN       NaN  ...
# 2008                       NaN       NaN       NaN       NaN       NaN  ...
# 2009                       NaN       NaN       NaN       NaN       NaN  ...
# 2010                       NaN       NaN  0.502748       NaN       NaN  ...
# 2011                       NaN       NaN       NaN       NaN       NaN  ...
# 2012                       NaN       NaN       NaN       NaN       NaN  ...
# 2013                       NaN  0.191011  0.510902       NaN       NaN  ...
# 2014                       NaN       NaN       NaN       NaN       NaN  ...
# 2015                       NaN       NaN  0.694553       NaN       NaN  ...
# 2016                       NaN       NaN       NaN       NaN       NaN  ...
# 2017                   0.69298       NaN  0.988412       NaN       NaN  ...
# 2018                       NaN       NaN       NaN       NaN       NaN  ...
# 2019                       NaN       NaN       NaN  0.614439  1.551489  ...
# 2020                   0.00000       NaN       NaN       NaN       NaN  ...
# 2021                   0.00000       NaN       NaN  1.000864       NaN  ...
# 2022                       NaN       NaN       NaN       NaN       NaN  ...
#
# country_name  Sao Tome and Principe   Senegal  Sierra Leone     Sudan  \
# year
# 2003                            NaN       NaN      0.210999       NaN
# 2004                            NaN       NaN           NaN       NaN
# 2005                            NaN       NaN           NaN       NaN
# 2006                            NaN       NaN           NaN       NaN
# 2008                            NaN       NaN           NaN       NaN
# 2009                            NaN       NaN           NaN       NaN
# 2010                            NaN       NaN           NaN       NaN
# 2011                            NaN  1.158080           NaN  0.879369
# 2012                            0.0       NaN           NaN       NaN
# 2013                            NaN  1.935800           NaN       NaN
# 2014                            NaN       NaN      0.625795       NaN
# 2015                            NaN  2.046850           NaN       NaN
# 2016                            NaN  1.161674           NaN       NaN
# 2017                            NaN  1.533930           NaN       NaN
# 2018                            NaN  1.846844      0.272927       NaN
# 2019                            NaN  4.217262           NaN       NaN
# 2020                            NaN       NaN           NaN       NaN
# 2021                            NaN       NaN           NaN       NaN
# 2022                            NaN       NaN           NaN       NaN
#
# country_name  Tanzania      Togo   Tunisia    Uganda    Zambia  Zimbabwe
# year
# 2003               NaN       NaN       NaN       NaN       NaN       NaN
# 2004               NaN       NaN       NaN       NaN       NaN       NaN
# 2005               NaN       NaN       NaN       NaN       NaN       NaN
# 2006               NaN       NaN       NaN       NaN       NaN       NaN
# 2008          0.128440       NaN       NaN       NaN       NaN       NaN
# 2009               NaN       NaN       NaN       NaN       NaN       NaN
# 2010          0.103473       NaN       NaN       NaN       NaN       NaN
# 2011               NaN  2.404216       NaN       NaN       NaN       NaN
# 2012          0.245774       NaN       NaN  0.360282       NaN       NaN
# 2013               NaN       NaN       NaN       NaN       NaN       NaN
# 2014               NaN       NaN       NaN       NaN       NaN       NaN
# 2015               NaN  1.623157       NaN       NaN       NaN       NaN
# 2016               NaN       NaN       NaN       NaN       NaN       NaN
# 2017               NaN  1.253972       NaN  0.000000  0.306559  0.621500
# 2018               NaN       NaN       NaN       NaN  0.216570       NaN
# 2019               NaN  1.571919  3.818086       NaN  0.335376  0.000000
# 2020          0.000000       NaN       NaN       NaN  0.443494       NaN
# 2021               NaN       NaN       NaN  0.000000  0.479708  0.379013
# 2022               NaN       NaN       NaN       NaN  0.317543       NaN
#
# [19 rows x 27 columns]

# %%
#WB_Educ_MS_df = WB_Educ_MS_df.rename(columns = {'value': 'Masters Educ. (% Pop.> 25yrs)'})
#WB_Educ_MS_df

# %%
data5 = {
    '2000 Lower Secondary Educ. (% Pop.> 25yrs)': (Educ_LS_table.iloc[0, 0:31]),
    '2022 Lower Secondary Educ. (% Pop.> 25yrs)': (Educ_LS_table.iloc[-1, 0:31]),
    '2000 Upper Secondary Educ. (% Pop.> 25yrs)': (Educ_US_table.iloc[0, 0:31]),
    '2022 Upper Secondary Educ. (% Pop.> 25yrs)': (Educ_US_table.iloc[-1, 0:31]),
    '2000 Masters Educ. (% Pop.> 25yrs)': (Educ_MS_table.iloc[0, 0:31]),
    '2022 Masters Educ. (% Pop.> 25yrs)': (Educ_MS_table.iloc[-1, 0:31])
}
summary_table5 = pd.DataFrame(data5)
summary_table5
# Out:
#                           2000 Lower Secondary Educ. (% Pop.> 25yrs)  \
# country_name
# Angola                                                           NaN
# Botswana                                                         NaN
# Burkina Faso                                                     NaN
# Central African Republic                                         NaN
# Chad                                                             NaN
# Djibouti                                                         NaN
# Egypt, Arab Rep.                                                 NaN
# Ethiopia                                                         NaN
# Ghana                                                            NaN
# Kenya                                                            NaN
# Lesotho                                                          NaN
# Liberia                                                          NaN
# Madagascar                                                       NaN
# Malawi                                                           NaN
# Mauritania                                                       NaN
# Mozambique                                                       NaN
# Nigeria                                                          NaN
# Rwanda                                                           NaN
# Samoa                                                            NaN
# Sao Tome and Principe                                            NaN
# Senegal                                                          NaN
# Sierra Leone                                                     NaN
# Somalia                                                          NaN
# Sudan                                                            NaN
# Tanzania                                                     5.98647
# Togo                                                             NaN
# Tunisia                                                          NaN
# Uganda                                                      11.51888
# Zambia                                                           NaN
# Zimbabwe                                                    46.01667
#
#                           2022 Lower Secondary Educ. (% Pop.> 25yrs)  \
# country_name
# Angola                                                           NaN
# Botswana                                                   70.004646
# Burkina Faso                                                     NaN
# Central African Republic                                         NaN
# Chad                                                             NaN
# Djibouti                                                         NaN
# Egypt, Arab Rep.                                                 NaN
# Ethiopia                                                         NaN
# Ghana                                                            NaN
# Kenya                                                      64.952110
# Lesotho                                                          NaN
# Liberia                                                          NaN
# Madagascar                                                       NaN
# Malawi                                                           NaN
# Mauritania                                                       NaN
# Mozambique                                                       NaN
# Nigeria                                                    69.982292
# Rwanda                                                     17.950159
# Samoa                                                            NaN
# Sao Tome and Principe                                            NaN
# Senegal                                                          NaN
# Sierra Leone                                                     NaN
# Somalia                                                    11.111570
# Sudan                                                            NaN
# Tanzania                                                         NaN
# Togo                                                             NaN
# Tunisia                                                          NaN
# Uganda                                                           NaN
# Zambia                                                     65.410141
# Zimbabwe                                                         NaN
#
#                           2000 Upper Secondary Educ. (% Pop.> 25yrs)  \
# country_name
# Angola                                                           NaN
# Botswana                                                         NaN
# Burkina Faso                                                     NaN
# Central African Republic                                         NaN
# Chad                                                             NaN
# Djibouti                                                         NaN
# Egypt, Arab Rep.                                                 NaN
# Ethiopia                                                         NaN
# Ghana                                                            NaN
# Kenya                                                            NaN
# Lesotho                                                          NaN
# Liberia                                                          NaN
# Madagascar                                                       NaN
# Malawi                                                           NaN
# Mauritania                                                       NaN
# Mozambique                                                       NaN
# Nigeria                                                          NaN
# Rwanda                                                           NaN
# Samoa                                                      63.037628
# Sao Tome and Principe                                            NaN
# Senegal                                                          NaN
# Sierra Leone                                                     NaN
# Somalia                                                          NaN
# Sudan                                                            NaN
# Tanzania                                                         NaN
# Togo                                                             NaN
# Tunisia                                                          NaN
# Uganda                                                           NaN
# Zambia                                                           NaN
# Zimbabwe                                                         NaN
#
#                           2022 Upper Secondary Educ. (% Pop.> 25yrs)  \
# country_name
# Angola                                                           NaN
# Botswana                                                   44.884315
# Burkina Faso                                                     NaN
# Central African Republic                                         NaN
# Chad                                                             NaN
# Djibouti                                                         NaN
# Egypt, Arab Rep.                                                 NaN
# Ethiopia                                                         NaN
# Ghana                                                            NaN
# Kenya                                                      37.576099
# Lesotho                                                          NaN
# Liberia                                                          NaN
# Madagascar                                                       NaN
# Malawi                                                           NaN
# Mauritania                                                       NaN
# Mozambique                                                       NaN
# Nigeria                                                    65.670242
# Rwanda                                                     13.457430
# Samoa                                                            NaN
# Sao Tome and Principe                                            NaN
# Senegal                                                          NaN
# Sierra Leone                                                     NaN
# Somalia                                                     9.807520
# Sudan                                                            NaN
# Tanzania                                                         NaN
# Togo                                                             NaN
# Tunisia                                                          NaN
# Uganda                                                           NaN
# Zambia                                                     38.453289
# Zimbabwe                                                         NaN
#
#                           2000 Masters Educ. (% Pop.> 25yrs)  \
# country_name
# Angola                                                   NaN
# Botswana                                                 NaN
# Burkina Faso                                             NaN
# Central African Republic                                 NaN
# Chad                                                     NaN
# Djibouti                                                 NaN
# Egypt, Arab Rep.                                         NaN
# Ethiopia                                                 NaN
# Ghana                                                    NaN
# Kenya                                                    NaN
# Lesotho                                                  NaN
# Liberia                                                  NaN
# Madagascar                                               NaN
# Malawi                                                   NaN
# Mauritania                                               NaN
# Mozambique                                               NaN
# Nigeria                                                  NaN
# Rwanda                                                   NaN
# Samoa                                                    NaN
# Sao Tome and Principe                                    NaN
# Senegal                                                  NaN
# Sierra Leone                                        0.210999
# Somalia                                                  NaN
# Sudan                                                    NaN
# Tanzania                                                 NaN
# Togo                                                     NaN
# Tunisia                                                  NaN
# Uganda                                                   NaN
# Zambia                                                   NaN
# Zimbabwe                                                 NaN
#
#                           2022 Masters Educ. (% Pop.> 25yrs)
# country_name
# Angola                                                   NaN
# Botswana                                            1.215302
# Burkina Faso                                             NaN
# Central African Republic                                 NaN
# Chad                                                     NaN
# Djibouti                                                 NaN
# Egypt, Arab Rep.                                         NaN
# Ethiopia                                                 NaN
# Ghana                                                    NaN
# Kenya                                                    NaN
# Lesotho                                                  NaN
# Liberia                                                  NaN
# Madagascar                                               NaN
# Malawi                                                   NaN
# Mauritania                                               NaN
# Mozambique                                               NaN
# Nigeria                                             2.852641
# Rwanda                                              0.633470
# Samoa                                                    NaN
# Sao Tome and Principe                                    NaN
# Senegal                                                  NaN
# Sierra Leone                                             NaN
# Somalia                                                  NaN
# Sudan                                                    NaN
# Tanzania                                                 NaN
# Togo                                                     NaN
# Tunisia                                                  NaN
# Uganda                                                   NaN
# Zambia                                              0.317543
# Zimbabwe                                                 NaN

# %%
# Save the DataFrame as a CSV
# Note: To avoid any issues later, use encoding="utf-8"
summary_table5.to_csv("Resources\WB_education_summary.csv", encoding="utf-8", index=False)
